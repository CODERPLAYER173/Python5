# %%
area_sqft = [
    800,900,1000,1100,1200,1300,1400,1500,1600,1700,
    1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,
    2800,2900,3000,3100,3200,3300,3400,3500,3600,3700,
    3800,3900,4000,4100,4200,4300,4400,4500,4600,4700,
    4800,4900,5000
]

price_usd = [
    150000,165000,180000,195000,215000,225000,245000,260000,275000,295000,
    310000,325000,345000,360000,380000,395000,410000,430000,445000,465000,
    480000,495000,515000,530000,550000,565000,585000,600000,620000,635000,
    655000,670000,690000,705000,725000,740000,760000,775000,795000,810000,
    830000,845000,865000
]

# %%
import  matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model  import  LinearRegression
import seaborn as sns
# %matplotlib inline
