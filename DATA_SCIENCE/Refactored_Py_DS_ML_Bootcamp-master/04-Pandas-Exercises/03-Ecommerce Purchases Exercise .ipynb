# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd

# %%
econ = pd.read_csv(filepath_or_buffer="Ecommerce Purchases.csv")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
econ.shape
# Out:
# (10000, 14)

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
print(econ["Purchase Price"].mean())
# Out:
# np.float64(50.347302)

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
print(econ["Purchase Price"].max())
# Out:
# 99.99

# %%
print(econ["Purchase Price"].min())
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
a =econ.loc[econ["Language"] == "en"]
a["Language"].count()
# Out:
# np.int64(1098)

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
econ[econ["Job"] == "Lawyer"].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
econ["AM or PM"].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
a = econ["Job"].value_counts().head(5)
print(a)
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
# Name: count, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
a = econ.loc[econ["Lot"] == "90 WT"]
print(a["Purchase Price"])
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
b = econ.loc[econ["Credit Card"] == 4926535242672853]
print(b["Email"])
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: str

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
econ.loc[(econ["CC Provider"] == "American Express") &(econ["Purchase Price"] > 95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
a = econ["CC Exp Date"].tolist()
lis1= []
for x in range(len(a)):
    if "25"  in a[x]:
        lis1.append([x])
print(len(lis1))
# Out:
# 1033

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
# Out:
# Email
# ynguyen@gmail.com       2
# david80@hotmail.com     2
# krodriguez@yahoo.com    2
# ozimmerman@yahoo.com    2
# adam19@yahoo.com        2
# Name: count, dtype: int64

# %% [markdown]
# # Great Job!
