# %%
import numpy as np
np_list = np.arrange(0,11)
print(np_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 np_list = np.array(0,11)
#       3 print(np_list)
#
# TypeError: Cannot interpret '11' as a data type
